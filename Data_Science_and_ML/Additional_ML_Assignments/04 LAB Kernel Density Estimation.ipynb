# %% [markdown]
# # Kernel Density Estimation

# %% [markdown]
# **Write and execute R code in the code cells per the instructions.  The expected results are provided for you directly following the code cells.**

# %%
f = "setup.R"; for (i in 1:10) { if (file.exists(f)) break else f = paste0("../", f) }; source(f)
# Out:
# <p style="text-align:center; font-size:10px;">
# .................................................... start of document ....................................................
# </p>

# %% [markdown]
# ## Data

# %%
data = data.frame(x1=c(2.5, 2.0, 2.0, 2.1, 8.0, 2.0, 10.0, 10.5, 3.0, 2.5, 3.0, 8.0, 1.0, 1.5),
                  x2=c(5.0, 5.0, 5.0, 4.0, 4.0, 5.5,  6.0,  3.0, 6.0, 6.0, 6.1, 6.0, 1.0, 6.0))
data
# Out:
#    x1   x2
# 1   2.5 5.0
# 2   2.0 5.0
# 3   2.0 5.0
# 4   2.1 4.0
# 5   8.0 4.0
# 6   2.0 5.5
# 7  10.0 6.0
# 8  10.5 3.0
# 9   3.0 6.0
# 10  2.5 6.0
# 11  3.0 6.1
# 12  8.0 6.0
# 13  1.0 1.0
# 14  1.5 6.0

# %% [markdown]
# ## Problem 1
#
# Estimate density of x1 distribution.
#
# Plot the estimated density of the x1 distribution, using a Gaussian kernel at bandwidth 1, scaled horizontally 0 to 10.
#
# You may want to use these function(s):
#
# * geom_density()

# %%
ggplot(data) + xlim(0, 10) +
geom_density(aes(x1), kernel="gaussian", bw=1)
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density).”
# plot without title

# %% [markdown]
# ## Problem 2
#
# Compare density estimates of the x1 variable distribution at various bandwidths.
#
# Plot the estimated densities of the x1 variable distribution, using a Gaussian kernel at bandwidths 2, 1, 0.5, and 0.2, overlayed and color-coded by bandwidth, scaled horizontally 0 to 10.
#
# You may want to use these function(s):
# * geom_density()
#
# Use `geom_density(........, alpha=0.3))` to make the fill transparent.

# %%
ggplot(data) + xlim(0, 10) + 
geom_density(aes(x1), kernel="gaussian", bw=1, fill=PALETTE[2], alpha=0.3)
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density).”
# plot without title

# %%
ggplot(data) + xlim(0, 10) +
geom_density(aes(x1), kernel="gaussian", bw=2, fill=PALETTE[1], alpha=0.3) + 
geom_density(aes(x1), kernel="gaussian", bw=1, fill=PALETTE[2], alpha=0.3) + 
geom_density(aes(x1), kernel="gaussian", bw=0.5, fill=PALETTE[3], alpha=0.3) + 
geom_density(aes(x1), kernel="gaussian", bw=0.2, fill=PALETTE[4], alpha=0.3)
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density).”
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density).”
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density).”
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density).”
# plot without title

# %% [markdown]
# ## Problem 3
#
# Plot the estimated density of x1 and x2 distributions taken together, using a Gaussian kernel at bandwidths 100, 10, 5, and 1, scaled horizontally and vertically 0 to 10, one plot for each bandwidth.  Show the original observations upon which the density is estimated.
#
# You may want to use these function(s):
# * geom_polygon()
# * geom_density_2d()
# * scale_fill_continuous()
# * geom_point()
#
#
# Use `geom_polygon(aes(.........., fill=stat(level), alpha=stat(level), .........., stat="density2d")` to fill.<br>
# Use `scale_fill_continuous(low="yellow", high="red")` to make the fill span from yellow to red.

# %%
output_size(4, 4)
ggplot(data) + xlim(0,10) + ylim(0,10) +
geom_polygon(aes(x=x1, y=x2, fill=stat(level), alpha=stat(level)), h=c(100, 100), bins=100, stat="density2d") +
geom_density_2d(aes(x=x1, y=x2), h=c(100, 100), bins=20) +
scale_fill_continuous(low="yellow", high="red") +
geom_point(aes(x=x1, y=x2)) +
theme.no_legend
output_size(restore)
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density2d).”
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density2d).”
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
output_size(4, 4)
ggplot(data) + xlim(0,10) + ylim(0,10) +
geom_polygon(aes(x=x1, y=x2, fill=stat(level), alpha=stat(level)), h=c(5, 5), bins=100, stat="density2d") +
geom_density_2d(aes(x=x1, y=x2), h=c(5, 5), bins=20) +
scale_fill_continuous(low="yellow", high="red") +
geom_point(aes(x=x1, y=x2)) +
theme.no_legend
output_size(restore)
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density2d).”
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density2d).”
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
output_size(4, 4)
ggplot(data) + xlim(0,10) + ylim(0,10) +
geom_polygon(aes(x=x1, y=x2, fill=stat(level), alpha=stat(level)), h=c(10, 10), bins=100, stat="density2d") +
geom_density_2d(aes(x=x1, y=x2), h=c(10, 10), bins=20) +
scale_fill_continuous(low="yellow", high="red") +
geom_point(aes(x=x1, y=x2)) +
theme.no_legend
output_size(restore)
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density2d).”
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density2d).”
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
output_size(4, 4)
ggplot(data) + xlim(0,10) + ylim(0,10) +
geom_polygon(aes(x=x1, y=x2, fill=stat(level), alpha=stat(level)), h=c(1, 1), bins=100, stat="density2d") +
geom_density_2d(aes(x=x1, y=x2), h=c(1, 1), bins=20) +
scale_fill_continuous(low="yellow", high="red") +
geom_point(aes(x=x1, y=x2)) +
theme.no_legend
output_size(restore)
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density2d).”
# Warning message:
# “Removed 1 rows containing non-finite values (stat_density2d).”
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ## Problem 4
#
# Determine the probability that a new observation will measure 1 < x1 < 3. Base the probability on a kernel density estimate using Gaussian kernel, standard deviation 1, estimated over the range 0 to 10.  Set calculation resolution to 500.
#
# You may want to use these function(s):
# * density()
# * approxfun()
# * integrate()
#
# Use `density(......., n=500)` to set calculation resolution to 500.
# Use `integrate(........)$value` to get the value of the integration.

# %%
d = density(data$x1, kernel="gaussian", bw=1, from=0, to=10, n=500)
pdf = approxfun(d)
data.frame(probability_x1_is_1_to_3=integrate(pdf, 1, 3)$value)
# Out:
#   probability_x1_is_1_to_3
# 1 0.431128

# %% [markdown]
# <font size=1;>
# <p style="text-align: left;">
# Copyright (c) Berkeley Data Analytics Group, LLC
# <span style="float: right;">
# Document revised Februray 9, 2020
# </span>
# </p>
# </font>
